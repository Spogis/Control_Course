# %%
pip install control

# %%
import control
import matplotlib.pyplot as plt

# %%
# Define transfer function of the system
s = control.tf('s')

# %% [markdown]
# ## Process  - Overdamped Second Order System

# %%
#Natural Period of Oscillation
Tau = 200

#Damping Factor (zeta)
Zeta = 1.5

#Process Gain
K = 1.0

# %%
A = Tau**2
B = 2*Zeta*Tau
C = 1
sys = K/(A*s**2 + B*s + 1)
sys
# Out:
# TransferFunction(array([1.]), array([4.e+04, 6.e+02, 1.e+00]))

# %%
# Simulate step response
t, y = control.step_response(sys)

# %%
# Plot step response
plt.plot(t, y)
plt.xlabel('Time (s)')
plt.ylabel('Output')
plt.title('System Step Response')
plt.grid()
plt.show()

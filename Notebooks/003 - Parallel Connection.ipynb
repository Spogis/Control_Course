# %%
pip install control

# %%
import control
import matplotlib.pyplot as plt

# %%
# Define transfer function of the system
s = control.tf('s')

# %% [markdown]
# ## Process

# %%
G1  = 1/(50*s+1)

# %%
G2  = 10/(350*s+1)

# %%
sys = control.parallel(G1,G2)
sys
# Out:
# TransferFunction(array([850,  11]), array([17500,   400,     1]))

# %%
# Simulate step response
t, y = control.step_response(sys)

# %%
# Plot step response
plt.plot(t, y)
plt.xlabel('Time (s)')
plt.ylabel('Output')
plt.title('System Step Response')
plt.grid()
plt.show()
